# %%
import ee
import folium

# %%
# ee.Authenticate()
ee.Initialize()

# %%
import ee
import geopandas as gpd
import shapely.geometry

# Initialize Earth Engine
ee.Initialize()

# Define the GeoJSON
geoJSON = {
  "type": "FeatureCollection",
  "features": [
    {
      "type": "Feature",
      "properties": {},
      "geometry": {
        "coordinates": [
          [
            100.67799289874142,
            6.339057689337892
          ],
          [
            100.67596196772081,
            6.3382887311459655
          ],
          [
            100.67522051671278,
            6.336943051553064
          ],
          [
            100.67264155668596,
            6.326561976772766
          ],
          [
            100.6766711817279,
            6.325216266618256
          ],
          [
            100.67841197974587,
            6.326369732679765
          ],
          [
            100.68079751777259,
            6.326241569910792
          ],
          [
            100.68086199177264,
            6.327010546046168
          ],
          [
            100.68150673177979,
            6.327491155548643
          ],
          [
            100.68131330977798,
            6.330374803178657
          ],
          [
            100.68095870277352,
            6.331047651975837
          ],
          [
            100.68150673177979,
            6.332201105017177
          ],
          [
            100.68260278979051,
            6.331496217353248
          ],
          [
            100.68366661080216,
            6.331303975096517
          ],
          [
            100.684601483812,
            6.331848661305088
          ],
          [
            100.6842468768092,
            6.332681709689936
          ],
          [
            100.68518174981904,
            6.3354051277208185
          ],
          [
            100.68421463980837,
            6.338160571336402
          ],
          [
            100.6780251357423,
            6.339057689337892
          ]
        ],
        "type": "LineString"
      }
    }
  ]
}

# %%
# Convert the geoJSON to a geometry object
aoi = ee.Geometry(geoJSON)

# Load the Landsat 7 NDVI image collection
collection = ee.ImageCollection('LANDSAT/LE07/C01/T1_32DAY_NDVI') \
                .filterDate('2020-01-1', '2023-03-17') \
                .filterBounds(aoi)

# Select the NDVI band and colorize it
image = collection.select('NDVI').mosaic()
colorized = image.visualize(min=0, max=1, palette=['FFFFFF', 'CE7E45', 'DF923D', 'F1B555', 'FCD163', '99B718', '74A901', '66A000', '529400', '3E8601', '207401', '056201', '004C00', '023B01', '012E01', '011D01', '011301'])

# Add the colorized image to the map
Map = ee.batch.Export.image.toDrive(image=colorized,
                                     description='Colo
